# %%
import numpy as np
import pandas as pd
import matplotlib as plt

# %matplotlib inline

import statsmodels.api as sm
import statsmodels.formula.api as smf

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def OSR2(model, df_train, df_test, dependent_var):   
    y_test = df_test[dependent_var]
    y_pred = model.predict(df_test)
    SSE = np.sum((y_test - y_pred)**2)
    SST = np.sum((y_test - np.mean(df_train[dependent_var]))**2)    
    return 1 - SSE/SST

# %%
def VIF(df, columns):
    values = sm.add_constant(df[columns]).values
    num_columns = len(columns)+1
    vif = [variance_inflation_factor(values, i) for i in range(num_columns)]
    return pd.Series(vif[1:], index=columns)

# %%
DoD = pd.read_csv('Data_Master_2.csv')

# %%
DoD.info()
DoD.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Dates                              507 non-null    object
#  1   Date                               507 non-null    int64
#  2   Bitcoin_Volume                     507 non-null    float64
#  3   Bitcoin_Price                      507 non-null    float64
#  4   Bitcoin_Price_Close                507 non-null    float64
#  5   Bitcoin_Price_Previous_Day_Open    507 non-null    float64
#  6   Bitcoin_Price_One_Week_Prior_Open  507 non-null    float64
#  7   Ethereum_Price                     507 non-null    float64
#  8   Doge_Price                         507 non-null    float64
#  9   Litecoin_Price                     507 non-null    float64
#  10  SP500                              507 non-null    float64
#  11  UST_1Y_Maturity                    507 non-null    float64
#  12  UST_10Y_Maturity                   507 non-null    float64
#  13  Crude_Oil                          507 non-null    float64
#  14  Gold                               507 non-null    float64
#  15  Copper                             507 non-null    float64
#  16  Corn                               507 non-null    float64
#  17  Singapore_Dollar                   507 non-null    float64
#  18  Euro                               507 non-null    float64
#  19  All_Twitter_Posts                  507 non-null    int64
#  20  Positive_Tweets                    507 non-null    int64
#  21  Negative_Tweet                     507 non-null    int64
#  22  Neutral_Tweets                     507 non-null    int64
#  23  Tweet_Average_Sentiment            507 non-null    float64
#  24  News_Article_Count                 507 non-null    int64
#  25  News_Sentiment                     507 non-null    float64
#  26  Crypto_Global_Ranking              507 non-null    float64
#  27  BTC_Price_Movement_DOD_UD          507 non-null    object
#  28  BTC_Price_Movement_DOD_10          507 non-null    int64
#  29  BTC_Price_Movement_ID_UD           507 non-null    object
#  30  BTC_Price_Movement_ID_10           507 non-null    int64
# dtypes: float64(20), int64(8), object(3)
# memory usage: 122.9+ KB
#         Dates  Date  Bitcoin_Volume  Bitcoin_Price  Bitcoin_Price_Close  \
# 0  11-10-2021     1    4.873083e+10    54734.12500          57484.78906
# 1  12-10-2021     2    3.096601e+10    57526.83203          56041.05859
#
#    Bitcoin_Price_Previous_Day_Open  Bitcoin_Price_One_Week_Prior_Open  \
# 0                      54952.82031                        48208.90625
# 1                      54734.12500                        49174.96094
#
#    Ethereum_Price  Doge_Price  Litecoin_Price  ...  Negative_Tweet  \
# 0     4636.174316    0.255709      261.262970  ...             220
# 1     3908.496094    0.164422      148.598297  ...             162
#
#    Neutral_Tweets  Tweet_Average_Sentiment  News_Article_Count  \
# 0             933                 0.075143                  12
# 1             657                 0.077401                   9
#
#    News_Sentiment  Crypto_Global_Ranking  BTC_Price_Movement_DOD_UD  \
# 0        0.058515                   56.0                         Up
# 1        0.116162                   56.0                         Up
#
#    BTC_Price_Movement_DOD_10  BTC_Price_Movement_ID_UD  \
# 0                          1                        Up
# 1                          1                      Down
#
#    BTC_Price_Movement_ID_10
# 0                         1
# 1                         0
#
# [2 rows x 31 columns]

# %%
DoD.corr()
# Out:
#                                        Date  Bitcoin_Volume  Bitcoin_Price  \
# Date                               1.000000       -0.116204      -0.899014
# Bitcoin_Volume                    -0.116204        1.000000       0.089039
# Bitcoin_Price                     -0.899014        0.089039       1.000000
# Bitcoin_Price_Close               -0.897526        0.084150       0.996753
# Bitcoin_Price_Previous_Day_Open   -0.900416        0.089478       0.996748
# Bitcoin_Price_One_Week_Prior_Open -0.907818        0.095841       0.978568
# Ethereum_Price                    -0.747528        0.096813       0.831093
# Doge_Price                        -0.724678        0.123685       0.840140
# Litecoin_Price                    -0.642903        0.064880       0.806627
# SP500                             -0.792102        0.007120       0.882743
# UST_1Y_Maturity                    0.987752       -0.074678      -0.907823
# UST_10Y_Maturity                   0.933488       -0.052530      -0.883583
# Crude_Oil                         -0.133440        0.001320      -0.065191
# Gold                              -0.188040       -0.221230       0.334774
# Copper                            -0.446760       -0.054529       0.550568
# Corn                               0.286608       -0.121245      -0.305010
# Singapore_Dollar                   0.000171        0.232848      -0.239800
# Euro                              -0.550212       -0.066661       0.679607
# All_Twitter_Posts                 -0.738314        0.177285       0.690087
# Positive_Tweets                   -0.756040        0.180533       0.730281
# Negative_Tweet                    -0.650482        0.203216       0.558523
# Neutral_Tweets                    -0.722833        0.164599       0.671817
# Tweet_Average_Sentiment           -0.067121       -0.052245       0.171710
# News_Article_Count                 0.422904        0.169132      -0.493507
# News_Sentiment                    -0.091727       -0.025556       0.148491
# Crypto_Global_Ranking             -0.791673        0.119622       0.805052
# BTC_Price_Movement_DOD_10          0.055865        0.044363       0.000310
# BTC_Price_Movement_ID_10          -0.007339       -0.006284      -0.024130
#
#                                    Bitcoin_Price_Close  \
# Date                                         -0.897526
# Bitcoin_Volume                                0.084150
# Bitcoin_Price                                 0.996753
# Bitcoin_Price_Close                           1.000000
# Bitcoin_Price_Previous_Day_Open               0.993515
# Bitcoin_Price_One_Week_Prior_Open             0.975817
# Ethereum_Price                                0.834162
# Doge_Price                                    0.843944
# Litecoin_Price                                0.810633
# SP500                                         0.884519
# UST_1Y_Maturity                              -0.906567
# UST_10Y_Maturity                             -0.883663
# Crude_Oil                                    -0.066349
# Gold                                          0.334425
# Copper                                        0.555010
# Corn                                         -0.308516
# Singapore_Dollar                             -0.245611
# Euro                                          0.683433
# All_Twitter_Posts                             0.688048
# Positive_Tweets                               0.730726
# Negative_Tweet                                0.549789
# Neutral_Tweets                                0.669755
# Tweet_Average_Sentiment                       0.181311
# News_Article_Count                           -0.494795
# News_Sentiment                                0.150321
# Crypto_Global_Ranking                         0.804744
# BTC_Price_Movement_DOD_10                     0.002828
# BTC_Price_Movement_ID_10                      0.027576
#
#                                    Bitcoin_Price_Previous_Day_Open  \
# Date                                                     -0.900416
# Bitcoin_Volume                                            0.089478
# Bitcoin_Price                                             0.996748
# Bitcoin_Price_Close                                       0.993515
# Bitcoin_Price_Previous_Day_Open                           1.000000
# Bitcoin_Price_One_Week_Prior_Open                         0.981838
# Ethereum_Price                                            0.827261
# Doge_Price                                                0.838087
# Litecoin_Price                                            0.804157
# SP500                                                     0.880326
# UST_1Y_Maturity                                          -0.909056
# UST_10Y_Maturity                                         -0.883463
# Crude_Oil                                                -0.064094
# Gold                                                      0.335318
# Copper                                                    0.546760
# Corn                                                     -0.301792
# Singapore_Dollar                                         -0.235219
# Euro                                                      0.676310
# All_Twitter_Posts                                         0.690869
# Positive_Tweets                                           0.729239
# Negative_Tweet                                            0.565154
# Neutral_Tweets                                            0.672465
# Tweet_Average_Sentiment                                   0.164868
# News_Article_Count                                       -0.494108
# News_Sentiment                                            0.149525
# Crypto_Global_Ranking                                     0.805362
# BTC_Price_Movement_DOD_10                                -0.037546
# BTC_Price_Movement_ID_10                                 -0.019915
#
#                                    Bitcoin_Price_One_Week_Prior_Open  \
# Date                                                       -0.907818
# Bitcoin_Volume                                              0.095841
# Bitcoin_Price                                               0.978568
# Bitcoin_Price_Close                                         0.975817
# Bitcoin_Price_Previous_Day_Open                             0.981838
# Bitcoin_Price_One_Week_Prior_Open                           1.000000
# Ethereum_Price                                              0.806810
# Doge_Price                                                  0.819745
# Litecoin_Price                                              0.782700
# SP500                                                       0.870621
# UST_1Y_Maturity                                            -0.917115
# UST_10Y_Maturity                                           -0.882012
# Crude_Oil                                                  -0.057436
# Gold                                                        0.333226
# Copper                                                      0.526286
# Corn                                                       -0.276084
# Singapore_Dollar                                           -0.207300
# Euro                                                        0.653997
# All_Twitter_Posts                                           0.706688
# Positive_Tweets                                             0.740848
# Negative_Tweet                                              0.595580
# Neutral_Tweets                                              0.687309
# Tweet_Average_Sentiment                                     0.147999
# News_Article_Count                                         -0.486302
# News_Sentiment                                              0.162304
# Crypto_Global_Ranking                                       0.811740
# BTC_Price_Movement_DOD_10                                  -0.063527
# BTC_Price_Movement_ID_10                                   -0.002707
#
#                                    Ethereum_Price  Doge_Price  Litecoin_Price  \
# Date                                    -0.747528   -0.724678       -0.642903
# Bitcoin_Volume                           0.096813    0.123685        0.064880
# Bitcoin_Price                            0.831093    0.840140        0.806627
# Bitcoin_Price_Close                      0.834162    0.843944        0.810633
# Bitcoin_Price_Previous_Day_Open          0.827261    0.838087        0.804157
# Bitcoin_Price_One_Week_Prior_Open        0.806810    0.819745        0.782700
# Ethereum_Price                           1.000000    0.930252        0.930939
# Doge_Price                               0.930252    1.000000        0.952772
# Litecoin_Price                           0.930939    0.952772        1.000000
# SP500                                    0.751162    0.726430        0.711483
# UST_1Y_Maturity                         -0.748897   -0.716360       -0.652219
# UST_10Y_Maturity                        -0.752540   -0.727948       -0.687559
# Crude_Oil                               -0.166382   -0.247507       -0.329606
# Gold                                     0.167007    0.135703        0.186215
# Copper                                   0.717633    0.646769        0.662862
# Corn                                    -0.360779   -0.460236       -0.463985
# Singapore_Dollar                        -0.361544   -0.402885       -0.496501
# Euro                                     0.813602    0.826049        0.847814
# All_Twitter_Posts                        0.472966    0.477942        0.425854
# Positive_Tweets                          0.508788    0.534061        0.479145
# Negative_Tweet                           0.357691    0.371096        0.319251
# Neutral_Tweets                           0.460762    0.452046        0.403177
# Tweet_Average_Sentiment                  0.153115    0.196249        0.197209
# News_Article_Count                      -0.513105   -0.554124       -0.547948
# News_Sentiment                           0.141201    0.175562        0.156214
# Crypto_Global_Ranking                    0.797146    0.830780        0.782314
# BTC_Price_Movement_DOD_10               -0.018580   -0.021312       -0.004101
# BTC_Price_Movement_ID_10                 0.025547    0.020270        0.037448
#
#                                       SP500  ...  All_Twitter_Posts  \
# Date                              -0.792102  ...          -0.738314
# Bitcoin_Volume                     0.007120  ...           0.177285
# Bitcoin_Price                      0.882743  ...           0.690087
# Bitcoin_Price_Close                0.884519  ...           0.688048
# Bitcoin_Price_Previous_Day_Open    0.880326  ...           0.690869
# Bitcoin_Price_One_Week_Prior_Open  0.870621  ...           0.706688
# Ethereum_Price                     0.751162  ...           0.472966
# Doge_Price                         0.726430  ...           0.477942
# Litecoin_Price                     0.711483  ...           0.425854
# SP500                              1.000000  ...           0.579748
# UST_1Y_Maturity                   -0.835748  ...          -0.740539
# UST_10Y_Maturity                  -0.878803  ...          -0.675234
# Crude_Oil                         -0.174441  ...           0.170910
# Gold                               0.398379  ...           0.303663
# Copper                             0.534992  ...           0.373464
# Corn                              -0.337274  ...          -0.062284
# Singapore_Dollar                  -0.332610  ...          -0.051951
# Euro                               0.642547  ...           0.402583
# All_Twitter_Posts                  0.579748  ...           1.000000
# Positive_Tweets                    0.610640  ...           0.979276
# Negative_Tweet                     0.444752  ...           0.942506
# Neutral_Tweets                     0.571089  ...           0.992417
# Tweet_Average_Sentiment            0.178137  ...          -0.094007
# News_Article_Count                -0.426185  ...          -0.191604
# News_Sentiment                     0.106677  ...           0.056137
# Crypto_Global_Ranking              0.730843  ...           0.530628
# BTC_Price_Movement_DOD_10          0.011631  ...          -0.020313
# BTC_Price_Movement_ID_10           0.030452  ...           0.051516
#
#                                    Positive_Tweets  Negative_Tweet  \
# Date                                     -0.756040       -0.650482
# Bitcoin_Volume                            0.180533        0.203216
# Bitcoin_Price                             0.730281        0.558523
# Bitcoin_Price_Close                       0.730726        0.549789
# Bitcoin_Price_Previous_Day_Open           0.729239        0.565154
# Bitcoin_Price_One_Week_Prior_Open         0.740848        0.595580
# Ethereum_Price                            0.508788        0.357691
# Doge_Price                                0.534061        0.371096
# Litecoin_Price                            0.479145        0.319251
# SP500                                     0.610640        0.444752
# UST_1Y_Maturity                          -0.754160       -0.647426
# UST_10Y_Maturity                         -0.694333       -0.574119
# Crude_Oil                                 0.129724        0.202145
# Gold                                      0.284022        0.244782
# Copper                                    0.387169        0.284938
# Corn                                     -0.127731       -0.039134
# Singapore_Dollar                         -0.080605        0.001045
# Euro                                      0.439213        0.320758
# All_Twitter_Posts                         0.979276        0.942506
# Positive_Tweets                           1.000000        0.908403
# Negative_Tweet                            0.908403        1.000000
# Neutral_Tweets                            0.950852        0.921278
# Tweet_Average_Sentiment                   0.036905       -0.238220
# News_Article_Count                       -0.223730       -0.126583
# News_Sentiment                            0.078046        0.027963
# Crypto_Global_Ranking                     0.565154        0.443019
# BTC_Price_Movement_DOD_10                -0.009299       -0.079083
# BTC_Price_Movement_ID_10                  0.062057        0.003026
#
#                                    Neutral_Tweets  Tweet_Average_Sentiment  \
# Date                                    -0.722833                -0.067121
# Bitcoin_Volume                           0.164599                -0.052245
# Bitcoin_Price                            0.671817                 0.171710
# Bitcoin_Price_Close                      0.669755                 0.181311
# Bitcoin_Price_Previous_Day_Open          0.672465                 0.164868
# Bitcoin_Price_One_Week_Prior_Open        0.687309                 0.147999
# Ethereum_Price                           0.460762                 0.153115
# Doge_Price                               0.452046                 0.196249
# Litecoin_Price                           0.403177                 0.197209
# SP500                                    0.571089                 0.178137
# UST_1Y_Maturity                         -0.728449                -0.070049
# UST_10Y_Maturity                        -0.663634                -0.100379
# Crude_Oil                                0.183196                -0.126078
# Gold                                     0.317569                 0.021707
# Copper                                   0.371869                 0.077850
# Corn                                    -0.027043                -0.177722
# Singapore_Dollar                        -0.044381                -0.122469
# Euro                                     0.385343                 0.112466
# All_Twitter_Posts                        0.992417                -0.094007
# Positive_Tweets                          0.950852                 0.036905
# Negative_Tweet                           0.921278                -0.238220
# Neutral_Tweets                           1.000000                -0.138319
# Tweet_Average_Sentiment                 -0.138319                 1.000000
# News_Article_Count                      -0.180133                -0.153120
# News_Sentiment                           0.047405                 0.065299
# Crypto_Global_Ranking                    0.511841                 0.111556
# BTC_Price_Movement_DOD_10               -0.014276                 0.100984
# BTC_Price_Movement_ID_10                 0.053606                 0.062621
#
#                                    News_Article_Count  News_Sentiment  \
# Date                                         0.422904       -0.091727
# Bitcoin_Volume                               0.169132       -0.025556
# Bitcoin_Price                               -0.493507        0.148491
# Bitcoin_Price_Close                         -0.494795        0.150321
# Bitcoin_Price_Previous_Day_Open             -0.494108        0.149525
# Bitcoin_Price_One_Week_Prior_Open           -0.486302        0.162304
# Ethereum_Price                              -0.513105        0.141201
# Doge_Price                                  -0.554124        0.175562
# Litecoin_Price                              -0.547948        0.156214
# SP500                                       -0.426185        0.106677
# UST_1Y_Maturity                              0.416724       -0.088943
# UST_10Y_Maturity                             0.441332       -0.070994
# Crude_Oil                                    0.276643       -0.025086
# Gold                                         0.014080        0.051124
# Copper                                      -0.211550        0.125357
# Corn                                         0.402185       -0.017447
# Singapore_Dollar                             0.162007       -0.087536
# Euro                                        -0.418226        0.131422
# All_Twitter_Posts                           -0.191604        0.056137
# Positive_Tweets                             -0.223730        0.078046
# Negative_Tweet                              -0.126583        0.027963
# Neutral_Tweets                              -0.180133        0.047405
# Tweet_Average_Sentiment                     -0.153120        0.065299
# News_Article_Count                           1.000000       -0.126874
# News_Sentiment                              -0.126874        1.000000
# Crypto_Global_Ranking                       -0.457451        0.154055
# BTC_Price_Movement_DOD_10                    0.070656       -0.029247
# BTC_Price_Movement_ID_10                    -0.007739        0.014065
#
#                                    Crypto_Global_Ranking  \
# Date                                           -0.791673
# Bitcoin_Volume                                  0.119622
# Bitcoin_Price                                   0.805052
# Bitcoin_Price_Close                             0.804744
# Bitcoin_Price_Previous_Day_Open                 0.805362
# Bitcoin_Price_One_Week_Prior_Open               0.811740
# Ethereum_Price                                  0.797146
# Doge_Price                                      0.830780
# Litecoin_Price                                  0.782314
# SP500                                           0.730843
# UST_1Y_Maturity                                -0.787931
# UST_10Y_Maturity                               -0.800425
# Crude_Oil                                      -0.162224
# Gold                                            0.092853
# Copper                                          0.502419
# Corn                                           -0.468811
# Singapore_Dollar                               -0.219716
# Euro                                            0.682003
# All_Twitter_Posts                               0.530628
# Positive_Tweets                                 0.565154
# Negative_Tweet                                  0.443019
# Neutral_Tweets                                  0.511841
# Tweet_Average_Sentiment                         0.111556
# News_Article_Count                             -0.457451
# News_Sentiment                                  0.154055
# Crypto_Global_Ranking                           1.000000
# BTC_Price_Movement_DOD_10                      -0.014667
# BTC_Price_Movement_ID_10                        0.025367
#
#                                    BTC_Price_Movement_DOD_10  \
# Date                                                0.055865
# Bitcoin_Volume                                      0.044363
# Bitcoin_Price                                       0.000310
# Bitcoin_Price_Close                                 0.002828
# Bitcoin_Price_Previous_Day_Open                    -0.037546
# Bitcoin_Price_One_Week_Prior_Open                  -0.063527
# Ethereum_Price                                     -0.018580
# Doge_Price                                         -0.021312
# Litecoin_Price                                     -0.004101
# SP500                                               0.011631
# UST_1Y_Maturity                                     0.048705
# UST_10Y_Maturity                                    0.023999
# Crude_Oil                                          -0.074898
# Gold                                                0.004946
# Copper                                              0.024976
# Corn                                               -0.046326
# Singapore_Dollar                                   -0.066212
# Euro                                                0.023505
# All_Twitter_Posts                                  -0.020313
# Positive_Tweets                                    -0.009299
# Negative_Tweet                                     -0.079083
# Neutral_Tweets                                     -0.014276
# Tweet_Average_Sentiment                             0.100984
# News_Article_Count                                  0.070656
# News_Sentiment                                     -0.029247
# Crypto_Global_Ranking                              -0.014667
# BTC_Price_Movement_DOD_10                           1.000000
# BTC_Price_Movement_ID_10                           -0.007090
#
#                                    BTC_Price_Movement_ID_10
# Date                                              -0.007339
# Bitcoin_Volume                                    -0.006284
# Bitcoin_Price                                     -0.024130
# Bitcoin_Price_Close                                0.027576
# Bitcoin_Price_Previous_Day_Open                   -0.019915
# Bitcoin_Price_One_Week_Prior_Open                 -0.002707
# Ethereum_Price                                     0.025547
# Doge_Price                                         0.020270
# Litecoin_Price                                     0.037448
# SP500                                              0.030452
# UST_1Y_Maturity                                   -0.010483
# UST_10Y_Maturity                                  -0.011775
# Crude_Oil                                          0.002211
# Gold                                               0.027143
# Copper                                             0.048541
# Corn                                               0.016804
# Singapore_Dollar                                  -0.044679
# Euro                                               0.017332
# All_Twitter_Posts                                  0.051516
# Positive_Tweets                                    0.062057
# Negative_Tweet                                     0.003026
# Neutral_Tweets                                     0.053606
# Tweet_Average_Sentiment                            0.062621
# News_Article_Count                                -0.007739
# News_Sentiment                                     0.014065
# Crypto_Global_Ranking                              0.025367
# BTC_Price_Movement_DOD_10                         -0.007090
# BTC_Price_Movement_ID_10                           1.000000
#
# [28 rows x 28 columns]

# %%
DoD_train = DoD[DoD['Date'] <= 405]
DoD_test = DoD[DoD['Date'] > 405]

len(DoD_train), len(DoD_test)
# Out:
# (405, 102)

# %% [markdown]
# ### Model1 -  All variables from the Dataframe

# %%
model1 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + All_Twitter_Posts + Positive_Tweets + Negative_Tweet + Neutral_Tweets + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.993
# Method:                 Least Squares   F-statistic:                     2530.
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:28:30   Log-Likelihood:                -3427.7
# No. Observations:                 405   AIC:                             6903.
# Df Residuals:                     381   BIC:                             6999.
# Df Model:                          23
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.499e+04   1.68e+04     -1.484      0.139   -5.81e+04    8128.589
# Bitcoin_Price_Previous_Day_Open       0.8780      0.025     35.319      0.000       0.829       0.927
# Bitcoin_Price_One_Week_Prior_Open     0.0171      0.026      0.665      0.506      -0.033       0.068
# Ethereum_Price                        0.4130      0.260      1.589      0.113      -0.098       0.924
# Doge_Price                         2265.7260   4251.626      0.533      0.594   -6093.863    1.06e+04
# Litecoin_Price                        0.7413      5.966      0.124      0.901     -10.990      12.472
# SP500                                 1.5275      0.578      2.641      0.009       0.390       2.665
# UST_1Y_Maturity                   -5.831e+04   3.12e+04     -1.868      0.062    -1.2e+05    3056.699
# UST_10Y_Maturity                   7.623e+04   4.98e+04      1.531      0.127   -2.17e+04    1.74e+05
# Crude_Oil                            14.6856     10.670      1.376      0.170      -6.293      35.665
# Gold                                  0.2140      2.043      0.105      0.917      -3.803       4.231
# Copper                             -325.2810    341.944     -0.951      0.342    -997.615     347.053
# Corn                               -207.3586    206.797     -1.003      0.317    -613.964     199.247
# Singapore_Dollar                   1.246e+04   8058.199      1.547      0.123   -3380.180    2.83e+04
# Euro                               4179.8516   5059.879      0.826      0.409   -5768.933    1.41e+04
# All_Twitter_Posts                    68.7624     93.502      0.735      0.463    -115.082     252.607
# Positive_Tweets                     -60.3824     93.600     -0.645      0.519    -244.419     123.654
# Negative_Tweet                      -90.2903     93.498     -0.966      0.335    -274.127      93.547
# Neutral_Tweets                      -68.4786     93.466     -0.733      0.464    -252.252     115.295
# Tweet_Average_Sentiment           -1.208e+04   7898.975     -1.529      0.127   -2.76e+04    3453.570
# News_Article_Count                    0.6345      3.841      0.165      0.869      -6.917       8.186
# News_Sentiment                     -562.1806   1269.080     -0.443      0.658   -3057.459    1933.098
# Crypto_Global_Ranking                -0.5541      6.178     -0.090      0.929     -12.701      11.593
# BTC_Price_Movement_ID_10           -427.4260    125.064     -3.418      0.001    -673.327    -181.525
# ==============================================================================
# Omnibus:                       27.029   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               96.541
# Skew:                           0.046   Prob(JB):                     1.09e-21
# Kurtosis:                       5.390   Cond. No.                     5.30e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.3e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model1, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9940605811282505

# %%
cols1 = ['Bitcoin_Price_Previous_Day_Open', 'Bitcoin_Price_One_Week_Prior_Open', 'Ethereum_Price', 'Doge_Price', 'Litecoin_Price', 'SP500', 'UST_1Y_Maturity', 'UST_10Y_Maturity', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'All_Twitter_Posts', 'Positive_Tweets', 'Negative_Tweet', 'Neutral_Tweets', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols1)
# Out:
# Bitcoin_Price_Previous_Day_Open          36.215249
# Bitcoin_Price_One_Week_Prior_Open        38.471346
# Ethereum_Price                           22.418116
# Doge_Price                               19.655883
# Litecoin_Price                           28.652092
# SP500                                    11.270754
# UST_1Y_Maturity                          62.728909
# UST_10Y_Maturity                         49.896973
# Crude_Oil                                 5.625838
# Gold                                      9.149555
# Copper                                    7.001230
# Corn                                      6.848355
# Singapore_Dollar                         10.893340
# Euro                                     25.619791
# All_Twitter_Posts                    543438.253540
# Positive_Tweets                       61270.908387
# Negative_Tweet                         7326.738367
# Neutral_Tweets                       176505.632923
# Tweet_Average_Sentiment                   2.393596
# News_Article_Count                        1.796955
# News_Sentiment                            1.097596
# Crypto_Global_Ranking                     4.615961
# BTC_Price_Movement_ID_10                  1.130904
# dtype: float64

# %% [markdown]
# # Model2 - Remove All_Tweets, Positive_Tweets, Negative_Tweets, Neutral_Tweet variable

# %%
model2 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     2778.
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:28:30   Log-Likelihood:                -3449.4
# No. Observations:                 405   AIC:                             6939.
# Df Residuals:                     385   BIC:                             7019.
# Df Model:                          19
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.341e+04   1.75e+04     -1.335      0.183   -5.79e+04    1.11e+04
# Bitcoin_Price_Previous_Day_Open       0.9235      0.025     36.925      0.000       0.874       0.973
# Bitcoin_Price_One_Week_Prior_Open     0.0016      0.027      0.059      0.953      -0.051       0.054
# Ethereum_Price                        0.3060      0.265      1.154      0.249      -0.215       0.827
# Doge_Price                         2859.4783   4445.711      0.643      0.520   -5881.433    1.16e+04
# Litecoin_Price                        0.5661      6.246      0.091      0.928     -11.715      12.847
# SP500                                 1.7014      0.599      2.842      0.005       0.524       2.878
# UST_1Y_Maturity                   -4.601e+04   3.19e+04     -1.440      0.151   -1.09e+05    1.68e+04
# UST_10Y_Maturity                   5.549e+04   5.17e+04      1.074      0.283   -4.61e+04    1.57e+05
# Crude_Oil                            15.9177     11.158      1.427      0.155      -6.021      37.856
# Gold                                 -1.1620      2.131     -0.545      0.586      -5.353       3.029
# Copper                             -116.2572    354.681     -0.328      0.743    -813.611     581.097
# Corn                                -99.9754    210.493     -0.475      0.635    -513.835     313.884
# Singapore_Dollar                   1.086e+04   8412.424      1.291      0.198   -5680.637    2.74e+04
# Euro                               2991.9005   5276.413      0.567      0.571   -7382.292    1.34e+04
# Tweet_Average_Sentiment            1.243e+04   5935.033      2.094      0.037     756.069    2.41e+04
# News_Article_Count                    2.3591      3.978      0.593      0.554      -5.462      10.181
# News_Sentiment                     -233.6031   1326.932     -0.176      0.860   -2842.543    2375.337
# Crypto_Global_Ranking                -1.9435      6.429     -0.302      0.763     -14.584      10.697
# BTC_Price_Movement_ID_10           -245.7849    127.670     -1.925      0.055    -496.802       5.232
# ==============================================================================
# Omnibus:                       32.098   Durbin-Watson:                   1.940
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              137.272
# Skew:                          -0.010   Prob(JB):                     1.56e-30
# Kurtosis:                       5.852   Cond. No.                     5.22e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.22e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model2, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9941540314229251

# %%
cols2 = ['Bitcoin_Price_Previous_Day_Open', 'Bitcoin_Price_One_Week_Prior_Open', 'Ethereum_Price', 'Doge_Price', 'Litecoin_Price', 'SP500', 'UST_1Y_Maturity', 'UST_10Y_Maturity', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols2)
# Out:
# Bitcoin_Price_Previous_Day_Open      33.274298
# Bitcoin_Price_One_Week_Prior_Open    37.241637
# Ethereum_Price                       21.167725
# Doge_Price                           19.508081
# Litecoin_Price                       28.504078
# SP500                                10.963073
# UST_1Y_Maturity                      59.647002
# UST_10Y_Maturity                     48.760012
# Crude_Oil                             5.584900
# Gold                                  9.039114
# Copper                                6.837374
# Corn                                  6.440558
# Singapore_Dollar                     10.776485
# Euro                                 25.288473
# Tweet_Average_Sentiment               1.226606
# News_Article_Count                    1.749926
# News_Sentiment                        1.089209
# Crypto_Global_Ranking                 4.537515
# BTC_Price_Movement_ID_10              1.069765
# dtype: float64

# %% [markdown]
# # Model3 - Remove UST_1Y_Maturity

# %%
model3 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.993
# Model:                            OLS   Adj. R-squared:                  0.992
# Method:                 Least Squares   F-statistic:                     2924.
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):               0.00
# Time:                        15:28:30   Log-Likelihood:                -3450.5
# No. Observations:                 405   AIC:                             6939.
# Df Residuals:                     386   BIC:                             7015.
# Df Model:                          18
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.843e+04   1.72e+04     -1.652      0.099   -6.23e+04    5399.076
# Bitcoin_Price_Previous_Day_Open       0.9272      0.025     37.215      0.000       0.878       0.976
# Bitcoin_Price_One_Week_Prior_Open     0.0176      0.024      0.728      0.467      -0.030       0.065
# Ethereum_Price                        0.2709      0.264      1.025      0.306      -0.249       0.791
# Doge_Price                         2528.0022   4445.921      0.569      0.570   -6213.251    1.13e+04
# Litecoin_Price                       -0.0079      6.242     -0.001      0.999     -12.280      12.265
# SP500                                 1.7110      0.599      2.854      0.005       0.532       2.890
# UST_10Y_Maturity                  -9452.5628   2.52e+04     -0.375      0.708    -5.9e+04    4.01e+04
# Crude_Oil                            22.5499     10.178      2.216      0.027       2.539      42.560
# Gold                                 -2.1285      2.026     -1.051      0.294      -6.112       1.855
# Copper                              -75.4205    354.037     -0.213      0.831    -771.503     620.662
# Corn                                -17.8299    202.899     -0.088      0.930    -416.755     381.095
# Singapore_Dollar                   1.345e+04   8228.698      1.635      0.103   -2724.896    2.96e+04
# Euro                               4982.5360   5099.223      0.977      0.329   -5043.193     1.5e+04
# Tweet_Average_Sentiment            1.161e+04   5916.308      1.963      0.050     -20.458    2.32e+04
# News_Article_Count                    2.4128      3.983      0.606      0.545      -5.419      10.245
# News_Sentiment                     -267.4398   1328.568     -0.201      0.841   -2879.576    2344.696
# Crypto_Global_Ranking                -2.7482      6.414     -0.428      0.669     -15.358       9.862
# BTC_Price_Movement_ID_10           -229.6654    127.355     -1.803      0.072    -480.061      20.730
# ==============================================================================
# Omnibus:                       32.476   Durbin-Watson:                   1.947
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              139.858
# Skew:                          -0.039   Prob(JB):                     4.27e-31
# Kurtosis:                       5.878   Cond. No.                     2.31e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.31e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model3, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9945964408414276

# %%
cols3 = ['Bitcoin_Price_Previous_Day_Open', 'Bitcoin_Price_One_Week_Prior_Open', 'Ethereum_Price', 'Doge_Price', 'Litecoin_Price', 'SP500', 'UST_10Y_Maturity', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols3)
# Out:
# Bitcoin_Price_Previous_Day_Open      32.928171
# Bitcoin_Price_One_Week_Prior_Open    30.713864
# Ethereum_Price                       20.988672
# Doge_Price                           19.455791
# Litecoin_Price                       28.388028
# SP500                                10.961722
# UST_10Y_Maturity                     11.597570
# Crude_Oil                             4.633561
# Gold                                  8.143054
# Copper                                6.793672
# Corn                                  5.967620
# Singapore_Dollar                     10.282301
# Euro                                 23.553003
# Tweet_Average_Sentiment               1.215497
# News_Article_Count                    1.749773
# News_Sentiment                        1.088868
# Crypto_Global_Ranking                 4.503241
# BTC_Price_Movement_ID_10              1.061543
# dtype: float64

# %% [markdown]
# # Model4 - Remove Bitcoin_Price_Previous_Day_Open

# %%
model4 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.967
# Model:                            OLS   Adj. R-squared:                  0.965
# Method:                 Least Squares   F-statistic:                     658.7
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          2.08e-273
# Time:                        15:28:30   Log-Likelihood:                -3759.0
# No. Observations:                 405   AIC:                             7554.
# Df Residuals:                     387   BIC:                             7626.
# Df Model:                          17
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -1.633e+05    3.6e+04     -4.538      0.000   -2.34e+05   -9.25e+04
# Bitcoin_Price_One_Week_Prior_Open     0.7028      0.033     21.057      0.000       0.637       0.768
# Ethereum_Price                        0.0297      0.565      0.053      0.958      -1.082       1.141
# Doge_Price                         2.315e+04   9436.474      2.453      0.015    4593.072    4.17e+04
# Litecoin_Price                       23.9123     13.282      1.800      0.073      -2.201      50.026
# SP500                                 8.5502      1.221      7.005      0.000       6.150      10.950
# UST_10Y_Maturity                  -4.821e+04   5.39e+04     -0.894      0.372   -1.54e+05    5.78e+04
# Crude_Oil                           111.3414     21.165      5.261      0.000      69.729     152.954
# Gold                                 -5.7677      4.329     -1.332      0.184     -14.278       2.743
# Copper                             -164.2516    757.330     -0.217      0.828   -1653.248    1324.745
# Corn                               -401.5795    433.476     -0.926      0.355   -1253.841     450.682
# Singapore_Dollar                   7.843e+04   1.72e+04      4.559      0.000    4.46e+04    1.12e+05
# Euro                               2.717e+04   1.08e+04      2.508      0.013    5874.216    4.85e+04
# Tweet_Average_Sentiment            2.442e+04   1.26e+04      1.933      0.054    -421.772    4.93e+04
# News_Article_Count                    3.4218      8.521      0.402      0.688     -13.332      20.175
# News_Sentiment                    -2110.9099   2840.066     -0.743      0.458   -7694.799    3472.979
# Crypto_Global_Ranking               -36.8808     13.579     -2.716      0.007     -63.579     -10.183
# BTC_Price_Movement_ID_10           -980.2936    268.996     -3.644      0.000   -1509.170    -451.418
# ==============================================================================
# Omnibus:                       14.467   Durbin-Watson:                   0.497
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               31.979
# Skew:                           0.044   Prob(JB):                     1.14e-07
# Kurtosis:                       4.374   Cond. No.                     1.65e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.65e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model4, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9152728246047328

# %%
cols4 = ['Bitcoin_Price_One_Week_Prior_Open', 'Ethereum_Price', 'Doge_Price', 'Litecoin_Price', 'SP500', 'UST_10Y_Maturity', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols4)
# Out:
# Bitcoin_Price_One_Week_Prior_Open    12.836652
# Ethereum_Price                       20.976053
# Doge_Price                           19.153658
# Litecoin_Price                       28.087016
# SP500                                 9.931438
# UST_10Y_Maturity                     11.577800
# Crude_Oil                             4.378915
# Gold                                  8.124081
# Copper                                6.793363
# Corn                                  5.952207
# Singapore_Dollar                      9.819410
# Euro                                 23.230921
# Tweet_Average_Sentiment               1.211384
# News_Article_Count                    1.749692
# News_Sentiment                        1.087354
# Crypto_Global_Ranking                 4.411150
# BTC_Price_Movement_ID_10              1.034916
# dtype: float64

# %% [markdown]
# # Model5 - Remove Ethereum_Price, Litecoin_Price, Dogecoin_Price

# %%
model5 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     731.0
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          9.17e-270
# Time:                        15:28:30   Log-Likelihood:                -3778.1
# No. Observations:                 405   AIC:                             7586.
# Df Residuals:                     390   BIC:                             7646.
# Df Model:                          14
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -2.055e+05   3.64e+04     -5.641      0.000   -2.77e+05   -1.34e+05
# Bitcoin_Price_One_Week_Prior_Open     0.7922      0.030     26.804      0.000       0.734       0.850
# SP500                                 8.7152      1.204      7.240      0.000       6.349      11.082
# UST_10Y_Maturity                   3.989e+04   5.29e+04      0.755      0.451    -6.4e+04    1.44e+05
# Crude_Oil                           106.8788     21.761      4.911      0.000      64.094     149.663
# Gold                                 -7.6092      4.375     -1.739      0.083     -16.212       0.993
# Copper                              452.3340    745.814      0.606      0.545   -1013.985    1918.653
# Corn                               -880.7758    421.062     -2.092      0.037   -1708.610     -52.941
# Singapore_Dollar                   9.149e+04   1.76e+04      5.197      0.000    5.69e+04    1.26e+05
# Euro                               5.197e+04   1.05e+04      4.968      0.000    3.14e+04    7.25e+04
# Tweet_Average_Sentiment            3.654e+04    1.3e+04      2.815      0.005     1.1e+04    6.21e+04
# News_Article_Count                   -8.4386      8.646     -0.976      0.330     -25.438       8.561
# News_Sentiment                    -2789.7853   2949.128     -0.946      0.345   -8587.964    3008.393
# Crypto_Global_Ranking               -18.7370     13.717     -1.366      0.173     -45.706       8.232
# BTC_Price_Movement_ID_10           -887.7897    279.044     -3.182      0.002   -1436.408    -339.172
# ==============================================================================
# Omnibus:                        7.346   Durbin-Watson:                   0.426
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):               11.074
# Skew:                           0.071   Prob(JB):                      0.00394
# Kurtosis:                       3.798   Cond. No.                     1.56e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.56e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model5, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9063376405621735

# %%
cols5 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'UST_10Y_Maturity', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols5)
# Out:
# Bitcoin_Price_One_Week_Prior_Open     9.232110
# SP500                                 8.858079
# UST_10Y_Maturity                     10.204937
# Crude_Oil                             4.245119
# Gold                                  7.611823
# Copper                                6.041655
# Corn                                  5.150158
# Singapore_Dollar                      9.429922
# Euro                                 19.859645
# Tweet_Average_Sentiment               1.172229
# News_Article_Count                    1.652004
# News_Sentiment                        1.075182
# Crypto_Global_Ranking                 4.128009
# BTC_Price_Movement_ID_10              1.021267
# dtype: float64

# %% [markdown]
# # Model6 - Remove UST_10Y_Maturity

# %%
model6 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.963
# Model:                            OLS   Adj. R-squared:                  0.962
# Method:                 Least Squares   F-statistic:                     788.1
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          4.26e-271
# Time:                        15:28:30   Log-Likelihood:                -3778.4
# No. Observations:                 405   AIC:                             7585.
# Df Residuals:                     391   BIC:                             7641.
# Df Model:                          13
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -1.972e+05   3.47e+04     -5.681      0.000   -2.65e+05   -1.29e+05
# Bitcoin_Price_One_Week_Prior_Open     0.7885      0.029     27.074      0.000       0.731       0.846
# SP500                                 8.3182      1.082      7.687      0.000       6.191      10.446
# Crude_Oil                           105.2600     21.644      4.863      0.000      62.708     147.812
# Gold                                 -8.8331      4.062     -2.175      0.030     -16.818      -0.848
# Copper                              525.1048    739.147      0.710      0.478    -928.094    1978.304
# Corn                               -713.2480    357.589     -1.995      0.047   -1416.285     -10.211
# Singapore_Dollar                    8.95e+04   1.74e+04      5.145      0.000    5.53e+04    1.24e+05
# Euro                               5.027e+04   1.02e+04      4.924      0.000    3.02e+04    7.03e+04
# Tweet_Average_Sentiment            3.745e+04   1.29e+04      2.900      0.004    1.21e+04    6.28e+04
# News_Article_Count                   -8.7918      8.629     -1.019      0.309     -25.757       8.173
# News_Sentiment                    -2545.2805   2929.662     -0.869      0.385   -8305.141    3214.580
# Crypto_Global_Ranking               -19.5444     13.668     -1.430      0.154     -46.417       7.328
# BTC_Price_Movement_ID_10           -891.9265    278.836     -3.199      0.001   -1440.132    -343.721
# ==============================================================================
# Omnibus:                        7.219   Durbin-Watson:                   0.421
# Prob(Omnibus):                  0.027   Jarque-Bera (JB):               10.914
# Skew:                           0.060   Prob(JB):                      0.00427
# Kurtosis:                       3.795   Cond. No.                     1.11e+07
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model6, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.8993773956301776

# %%
cols6 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Euro', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols6)
# Out:
# Bitcoin_Price_One_Week_Prior_Open     8.974296
# SP500                                 7.166474
# Crude_Oil                             4.203872
# Gold                                  6.566017
# Copper                                5.940655
# Corn                                  3.718565
# Singapore_Dollar                      9.219864
# Euro                                 18.941777
# Tweet_Average_Sentiment               1.162073
# News_Article_Count                    1.647164
# News_Sentiment                        1.062205
# Crypto_Global_Ranking                 4.102897
# BTC_Price_Movement_ID_10              1.020873
# dtype: float64

# %% [markdown]
# # Model7 - Remove Euro variable

# %%
model7 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     804.0
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          1.86e-267
# Time:                        15:28:30   Log-Likelihood:                -3790.6
# No. Observations:                 405   AIC:                             7607.
# Df Residuals:                     392   BIC:                             7659.
# Df Model:                          12
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -5.599e+04   2.01e+04     -2.782      0.006   -9.56e+04   -1.64e+04
# Bitcoin_Price_One_Week_Prior_Open     0.8511      0.027     31.551      0.000       0.798       0.904
# SP500                                 6.8857      1.073      6.419      0.000       4.777       8.995
# Crude_Oil                           101.1697     22.260      4.545      0.000      57.407     144.933
# Gold                                -11.1379      4.152     -2.682      0.008     -19.302      -2.974
# Copper                             2634.1008    619.980      4.249      0.000    1415.200    3853.002
# Corn                              -1051.2744    361.190     -2.911      0.004   -1761.387    -341.162
# Singapore_Dollar                   2.747e+04   1.23e+04      2.225      0.027    3195.737    5.17e+04
# Tweet_Average_Sentiment            3.113e+04   1.32e+04      2.353      0.019    5120.920    5.71e+04
# News_Article_Count                  -16.3065      8.741     -1.866      0.063     -33.492       0.879
# News_Sentiment                    -3256.3255   3011.597     -1.081      0.280   -9177.228    2664.577
# Crypto_Global_Ranking                -5.3646     13.752     -0.390      0.697     -32.401      21.672
# BTC_Price_Movement_ID_10           -967.7788    286.545     -3.377      0.001   -1531.136    -404.421
# ==============================================================================
# Omnibus:                        3.516   Durbin-Watson:                   0.386
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                4.091
# Skew:                           0.036   Prob(JB):                        0.129
# Kurtosis:                       3.487   Cond. No.                     6.42e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model7, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9401686179189963

# %%
cols7 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Tweet_Average_Sentiment', 'News_Article_Count', 'News_Sentiment', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols7)
# Out:
# Bitcoin_Price_One_Week_Prior_Open    7.266960
# SP500                                6.648406
# Crude_Oil                            4.197679
# Gold                                 6.478796
# Copper                               3.945597
# Corn                                 3.581496
# Singapore_Dollar                     4.383781
# Tweet_Average_Sentiment              1.150574
# News_Article_Count                   1.595632
# News_Sentiment                       1.059624
# Crypto_Global_Ranking                3.920740
# BTC_Price_Movement_ID_10             1.017757
# dtype: float64

# %% [markdown]
# # Model8 - Remove News_Sentiment variable - low significance

# %%
model8 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Tweet_Average_Sentiment + News_Article_Count + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     876.7
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          1.10e-268
# Time:                        15:28:30   Log-Likelihood:                -3791.2
# No. Observations:                 405   AIC:                             7606.
# Df Residuals:                     393   BIC:                             7654.
# Df Model:                          11
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -5.654e+04   2.01e+04     -2.810      0.005   -9.61e+04    -1.7e+04
# Bitcoin_Price_One_Week_Prior_Open     0.8485      0.027     31.569      0.000       0.796       0.901
# SP500                                 6.9390      1.072      6.474      0.000       4.832       9.046
# Crude_Oil                           100.8728     22.263      4.531      0.000      57.104     144.642
# Gold                                -10.8676      4.146     -2.621      0.009     -19.018      -2.717
# Copper                             2636.8488    620.108      4.252      0.000    1417.705    3855.992
# Corn                              -1087.9374    359.673     -3.025      0.003   -1795.060    -380.815
# Singapore_Dollar                   2.751e+04   1.23e+04      2.228      0.026    3234.605    5.18e+04
# Tweet_Average_Sentiment            3.038e+04   1.32e+04      2.299      0.022    4401.354    5.63e+04
# News_Article_Count                  -15.8179      8.731     -1.812      0.071     -32.984       1.348
# Crypto_Global_Ranking                -6.5951     13.707     -0.481      0.631     -33.544      20.354
# BTC_Price_Movement_ID_10           -966.0927    286.602     -3.371      0.001   -1529.559    -402.627
# ==============================================================================
# Omnibus:                        3.608   Durbin-Watson:                   0.379
# Prob(Omnibus):                  0.165   Jarque-Bera (JB):                4.255
# Skew:                           0.029   Prob(JB):                        0.119
# Kurtosis:                       3.499   Cond. No.                     6.42e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.42e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model8, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9419982297115143

# %%
cols8 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Tweet_Average_Sentiment', 'News_Article_Count', 'Crypto_Global_Ranking', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols8)
# Out:
# Bitcoin_Price_One_Week_Prior_Open    7.212291
# SP500                                6.634364
# Crude_Oil                            4.197040
# Gold                                 6.455311
# Copper                               3.945530
# Corn                                 3.549932
# Singapore_Dollar                     4.383734
# Tweet_Average_Sentiment              1.147410
# News_Article_Count                   1.591368
# Crypto_Global_Ranking                3.893890
# BTC_Price_Movement_ID_10             1.017727
# dtype: float64

# %% [markdown]
# # Model9 - Remove Crypto_Global_Ranking

# %%
model9 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Tweet_Average_Sentiment + News_Article_Count + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model9.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.961
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     966.2
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          3.86e-270
# Time:                        15:28:31   Log-Likelihood:                -3791.3
# No. Observations:                 405   AIC:                             7605.
# Df Residuals:                     394   BIC:                             7649.
# Df Model:                          10
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                         -5.849e+04   1.97e+04     -2.970      0.003   -9.72e+04   -1.98e+04
# Bitcoin_Price_One_Week_Prior_Open     0.8420      0.023     36.330      0.000       0.796       0.888
# SP500                                 6.9458      1.071      6.487      0.000       4.841       9.051
# Crude_Oil                           100.1674     22.193      4.514      0.000      56.537     143.798
# Gold                                -10.5957      4.103     -2.582      0.010     -18.662      -2.529
# Copper                             2599.4326    614.612      4.229      0.000    1391.104    3807.761
# Corn                              -1042.1121    346.494     -3.008      0.003   -1723.320    -360.904
# Singapore_Dollar                   2.841e+04   1.22e+04      2.329      0.020    4429.042    5.24e+04
# Tweet_Average_Sentiment            3.086e+04   1.32e+04      2.345      0.020    4991.806    5.67e+04
# News_Article_Count                  -15.9211      8.720     -1.826      0.069     -33.065       1.223
# BTC_Price_Movement_ID_10           -973.8956    285.864     -3.407      0.001   -1535.905    -411.886
# ==============================================================================
# Omnibus:                        3.958   Durbin-Watson:                   0.376
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                4.734
# Skew:                           0.052   Prob(JB):                       0.0938
# Kurtosis:                       3.519   Cond. No.                     6.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model9, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.94081364542045

# %%
cols9 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Tweet_Average_Sentiment', 'News_Article_Count', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols9)
# Out:
# Bitcoin_Price_One_Week_Prior_Open    5.372873
# SP500                                6.633207
# Crude_Oil                            4.178839
# Gold                                 6.335405
# Copper                               3.883477
# Corn                                 3.300995
# Singapore_Dollar                     4.284425
# Tweet_Average_Sentiment              1.140640
# News_Article_Count                   1.590407
# BTC_Price_Movement_ID_10             1.014468
# dtype: float64

# %% [markdown]
# # Model10 - Remove News_Article_Count

# %%
model10 = smf.ols(formula='Bitcoin_Price ~ Bitcoin_Price_One_Week_Prior_Open + SP500 + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Tweet_Average_Sentiment + BTC_Price_Movement_ID_10',
data=DoD_train).fit()
print(model10.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          Bitcoin_Price   R-squared:                       0.960
# Model:                            OLS   Adj. R-squared:                  0.960
# Method:                 Least Squares   F-statistic:                     1067.
# Date:                Fri, 21 Apr 2023   Prob (F-statistic):          6.03e-271
# Time:                        15:28:31   Log-Likelihood:                -3793.0
# No. Observations:                 405   AIC:                             7606.
# Df Residuals:                     395   BIC:                             7646.
# Df Model:                           9
# Covariance Type:            nonrobust
# =====================================================================================================
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                          -5.68e+04   1.97e+04     -2.879      0.004   -9.56e+04    -1.8e+04
# Bitcoin_Price_One_Week_Prior_Open     0.8554      0.022     38.800      0.000       0.812       0.899
# SP500                                 6.8891      1.073      6.418      0.000       4.779       8.999
# Crude_Oil                            99.7046     22.257      4.480      0.000      55.948     143.461
# Gold                                -11.2065      4.101     -2.732      0.007     -19.270      -3.143
# Copper                             2582.6019    616.355      4.190      0.000    1370.855    3794.349
# Corn                              -1122.3955    344.706     -3.256      0.001   -1800.084    -444.707
# Singapore_Dollar                   2.788e+04   1.22e+04      2.280      0.023    3840.953    5.19e+04
# Tweet_Average_Sentiment            3.115e+04   1.32e+04      2.360      0.019    5201.030    5.71e+04
# BTC_Price_Movement_ID_10           -961.9196    286.632     -3.356      0.001   -1525.434    -398.405
# ==============================================================================
# Omnibus:                        4.050   Durbin-Watson:                   0.368
# Prob(Omnibus):                  0.132   Jarque-Bera (JB):                4.902
# Skew:                           0.049   Prob(JB):                       0.0862
# Kurtosis:                       3.530   Cond. No.                     6.30e+06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 6.3e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
OSR2(model10, DoD_train, DoD_test, 'Bitcoin_Price')
# Out:
# 0.9382203644879736

# %%
cols10 = ['Bitcoin_Price_One_Week_Prior_Open', 'SP500', 'Crude_Oil', 'Gold', 'Copper', 'Corn', 'Singapore_Dollar', 'Tweet_Average_Sentiment', 'BTC_Price_Movement_ID_10']
VIF(DoD_train, cols10)
# Out:
# Bitcoin_Price_One_Week_Prior_Open    4.833401
# SP500                                6.627623
# Crude_Oil                            4.178294
# Gold                                 6.293295
# Copper                               3.882604
# Corn                                 3.247833
# Singapore_Dollar                     4.282050
# Tweet_Average_Sentiment              1.140482
# BTC_Price_Movement_ID_10             1.013934
# dtype: float64

# %% [markdown]
# - Based on the model (Model10) the variables that are most significant to determine the price of Bitcoin are:
#     - Price of bitcoin from one week prior
#     - Price of the SP500 (USD)
#     - Price of crude oil (USD)
#     - Price of gold (USD)
#     - Price of copper (USD)
#     - Price of corn (USD)
#     - USD to SGD exchange rate
#     - Average twitter sentiment for the day
#     - Intraday price movement
#
# - Each of these variables have high significance (P > |t| value of less than 0.05)
# - Each of these variables have low multicollinearity amongst them (VIF values < 10)
# - Each of these variables are also avaiable online and updated daily making it easy to collect data
