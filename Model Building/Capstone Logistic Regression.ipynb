# %%
import numpy as np
import pandas as pd
import os

# %%
DoD = pd.read_csv("Data_Master_2.csv")
DoD.info()
DoD
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 507 entries, 0 to 506
# Data columns (total 31 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Dates                              507 non-null    object
#  1   Date                               507 non-null    int64
#  2   Bitcoin_Volume                     507 non-null    float64
#  3   Bitcoin_Price                      507 non-null    float64
#  4   Bitcoin_Price_Close                507 non-null    float64
#  5   Bitcoin_Price_Previous_Day_Open    507 non-null    float64
#  6   Bitcoin_Price_One_Week_Prior_Open  507 non-null    float64
#  7   Ethereum_Price                     507 non-null    float64
#  8   Doge_Price                         507 non-null    float64
#  9   Litecoin_Price                     507 non-null    float64
#  10  SP500                              507 non-null    float64
#  11  UST_1Y_Maturity                    507 non-null    float64
#  12  UST_10Y_Maturity                   507 non-null    float64
#  13  Crude_Oil                          507 non-null    float64
#  14  Gold                               507 non-null    float64
#  15  Copper                             507 non-null    float64
#  16  Corn                               507 non-null    float64
#  17  Singapore_Dollar                   507 non-null    float64
#  18  Euro                               507 non-null    float64
#  19  All_Twitter_Posts                  507 non-null    int64
#  20  Positive_Tweets                    507 non-null    int64
#  21  Negative_Tweet                     507 non-null    int64
#  22  Neutral_Tweets                     507 non-null    int64
#  23  Tweet_Average_Sentiment            507 non-null    float64
#  24  News_Article_Count                 507 non-null    int64
#  25  News_Sentiment                     507 non-null    float64
#  26  Crypto_Global_Ranking              507 non-null    float64
#  27  BTC_Price_Movement_DOD_UD          507 non-null    object
#  28  BTC_Price_Movement_DOD_10          507 non-null    int64
#  29  BTC_Price_Movement_ID_UD           507 non-null    object
#  30  BTC_Price_Movement_ID_10           507 non-null    int64
# dtypes: float64(20), int64(8), object(3)
# memory usage: 122.9+ KB
#           Dates  Date  Bitcoin_Volume  Bitcoin_Price  Bitcoin_Price_Close  \
# 0    11-10-2021     1    4.873083e+10    54734.12500          57484.78906
# 1    12-10-2021     2    3.096601e+10    57526.83203          56041.05859
# 2    13-10-2021     3    4.168425e+10    56038.25781          57401.09766
# 3    14-10-2021     4    3.661579e+10    57372.83203          57321.52344
# 4    15-10-2021     5    5.178008e+10    57345.90234          61593.94922
# ..          ...   ...             ...            ...                  ...
# 502  25-02-2023   503    1.610072e+10    23200.12500          23175.37500
# 503  26-02-2023   504    1.664453e+10    23174.15039          23561.21289
# 504  27-02-2023   505    2.266076e+10    23561.45117          23522.87109
# 505  28-02-2023   506    2.053536e+10    23521.83789          23147.35352
# 506  01-03-2023   507    1.390308e+10    23150.92969          23646.55078
#
#      Bitcoin_Price_Previous_Day_Open  Bitcoin_Price_One_Week_Prior_Open  \
# 0                        54952.82031                        48208.90625
# 1                        54734.12500                        49174.96094
# 2                        57526.83203                        51486.66406
# 3                        56038.25781                        55338.62500
# 4                        57372.83203                        53802.14453
# ..                               ...                                ...
# 502                      23946.00781                        24565.29688
# 503                      23200.12500                        24640.02734
# 504                      23174.15039                        24336.62305
# 505                      23561.45117                        24833.04883
# 506                      23521.83789                        24437.41797
#
#      Ethereum_Price  Doge_Price  Litecoin_Price  ...  Negative_Tweet  \
# 0       4636.174316    0.255709      261.262970  ...             220
# 1       3908.496094    0.164422      148.598297  ...             162
# 2       3606.201660    0.232572      177.628326  ...             119
# 3       3786.014160    0.232273      180.118393  ...             146
# 4       3862.634766    0.233782      188.814133  ...             392
# ..              ...         ...             ...  ...             ...
# 502     1594.914917    0.080786       93.263451  ...              44
# 503     1640.817139    0.082202       95.255623  ...              57
# 504     1634.326416    0.081354       94.086678  ...              73
# 505     1605.895142    0.080749       93.792778  ...              50
# 506     1214.778809    0.070468       75.602722  ...              58
#
#      Neutral_Tweets  Tweet_Average_Sentiment  News_Article_Count  \
# 0               933                 0.075143                  12
# 1               657                 0.077401                   9
# 2               697                 0.084999                   7
# 3               745                 0.080296                   4
# 4              1748                 0.064239                   1
# ..              ...                      ...                 ...
# 502             210                 0.079262                  23
# 503             195                 0.061385                  18
# 504             251                 0.066812                  53
# 505             233                 0.095058                  61
# 506             267                 0.059729                  41
#
#      News_Sentiment  Crypto_Global_Ranking  BTC_Price_Movement_DOD_UD  \
# 0          0.058515              56.000000                         Up
# 1          0.116162              56.000000                         Up
# 2          0.092929              56.000000                         Up
# 3          0.046465              56.000000                       Down
# 4          0.000000              56.000000                         Up
# ..              ...                    ...                        ...
# 502        0.147738              22.181818                       Down
# 503        0.038656              22.000000                       Down
# 504        0.085788              22.000000                         Up
# 505        0.015882              22.000000                         Up
# 506        0.079468              22.000000                       Down
#
#      BTC_Price_Movement_DOD_10  BTC_Price_Movement_ID_UD  \
# 0                            1                        Up
# 1                            1                      Down
# 2                            1                        Up
# 3                            0                      Down
# 4                            1                        Up
# ..                         ...                       ...
# 502                          0                      Down
# 503                          0                        Up
# 504                          1                      Down
# 505                          1                      Down
# 506                          0                        Up
#
#      BTC_Price_Movement_ID_10
# 0                           1
# 1                           0
# 2                           1
# 3                           0
# 4                           1
# ..                        ...
# 502                         0
# 503                         1
# 504                         0
# 505                         0
# 506                         1
#
# [507 rows x 31 columns]

# %%
DoD_train = DoD[data['Date'] <= 405]
DoD_test = DoD[data['Date'] > 405]

len(DoD_train), len(DoD_test)
# Out:
# (405, 102)

# %% [markdown]
# # Model 1

# %%
import statsmodels.formula.api as smf

logreg1 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Corn + Singapore_Dollar + Euro + All_Twitter_Posts + Positive_Tweets + Negative_Tweet + Neutral_Tweets + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
                   data = DoD_train).fit()
print(logreg1.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.479098
#          Iterations 8
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      378
# Method:                                  MLE   Df Model:                           26
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.3059
# Time:                               17:45:56   Log-Likelihood:                -194.03
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 2.722e-23
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           -53.1103     39.724     -1.337      0.181    -130.967      24.747
# Bitcoin_Volume                     1.092e-11   1.44e-11      0.760      0.447   -1.72e-11    3.91e-11
# Bitcoin_Price                         0.0017      0.000      6.349      0.000       0.001       0.002
# Bitcoin_Price_Close                5.762e-05      0.000      0.371      0.711      -0.000       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.558      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.99e-05     -3.665      0.000      -0.000      -0.000
# Ethereum_Price                       -0.0007      0.001     -1.228      0.219      -0.002       0.000
# Doge_Price                           -2.2044      9.515     -0.232      0.817     -20.853      16.444
# Litecoin_Price                       -0.0068      0.013     -0.513      0.608      -0.033       0.019
# SP500                                 0.0006      0.001      0.482      0.630      -0.002       0.003
# UST_1Y_Maturity                     -46.4208     67.201     -0.691      0.490    -178.133      85.291
# UST_10Y_Maturity                     89.4982    107.186      0.835      0.404    -120.583     299.580
# Crude_Oil                            -0.0262      0.023     -1.139      0.255      -0.071       0.019
# Gold                                  0.0009      0.004      0.197      0.844      -0.008       0.009
# Copper                                0.1756      0.734      0.239      0.811      -1.263       1.615
# Corn                                 -0.0337      0.446     -0.076      0.940      -0.908       0.840
# Singapore_Dollar                     22.2786     19.237      1.158      0.247     -15.425      59.982
# Euro                                 17.3868     11.251      1.545      0.122      -4.665      39.439
# All_Twitter_Posts                     0.0049      0.212      0.023      0.982      -0.410       0.420
# Positive_Tweets                      -0.0076      0.212     -0.036      0.971      -0.423       0.408
# Negative_Tweet                       -0.0100      0.212     -0.047      0.962      -0.425       0.405
# Neutral_Tweets                       -0.0018      0.212     -0.009      0.993      -0.417       0.413
# Tweet_Average_Sentiment              26.4990     18.180      1.458      0.145      -9.134      62.132
# News_Article_Count                    0.0026      0.009      0.300      0.764      -0.015       0.020
# News_Sentiment                       -1.4723      2.719     -0.542      0.588      -6.801       3.857
# Crypto_Global_Ranking                 0.0186      0.013      1.404      0.160      -0.007       0.045
# BTC_Price_Movement_ID_10              0.1927      0.346      0.556      0.578      -0.486       0.872
# =====================================================================================================

# %% [markdown]
# ## Model 2 deleting Corn, All_Twitter_Posts, Positive_Tweets, Negative_Tweet, Neutral_Tweets

# %%
logreg2 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Gold + Copper + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Article_Count + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
                   data = DoD_train).fit()
print(logreg2.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.481989
#          Iterations 7
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      383
# Method:                                  MLE   Df Model:                           21
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.3017
# Time:                               17:57:57   Log-Likelihood:                -195.21
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 4.668e-25
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           -47.7973     39.243     -1.218      0.223    -124.711      29.117
# Bitcoin_Volume                     1.119e-11   1.39e-11      0.803      0.422   -1.61e-11    3.85e-11
# Bitcoin_Price                         0.0016      0.000      6.331      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0001      0.000      0.700      0.484      -0.000       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.643      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.88e-05     -3.756      0.000      -0.000      -0.000
# Ethereum_Price                       -0.0006      0.001     -1.088      0.276      -0.002       0.000
# Doge_Price                           -3.9463      9.360     -0.422      0.673     -22.292      14.400
# Litecoin_Price                       -0.0086      0.013     -0.667      0.505      -0.034       0.017
# SP500                                 0.0006      0.001      0.481      0.631      -0.002       0.003
# UST_1Y_Maturity                     -49.0087     63.513     -0.772      0.440    -173.492      75.474
# UST_10Y_Maturity                     91.7760     92.306      0.994      0.320     -89.140     272.692
# Crude_Oil                            -0.0281      0.023     -1.240      0.215      -0.072       0.016
# Gold                                  0.0010      0.004      0.268      0.789      -0.007       0.009
# Copper                                0.2591      0.712      0.364      0.716      -1.137       1.655
# Singapore_Dollar                     19.7835     18.990      1.042      0.298     -17.436      57.003
# Euro                                 15.2682     11.138      1.371      0.170      -6.562      37.098
# Tweet_Average_Sentiment              20.8845     12.336      1.693      0.090      -3.294      45.063
# News_Article_Count                    0.0026      0.009      0.302      0.762      -0.014       0.019
# News_Sentiment                       -1.6576      2.702     -0.614      0.540      -6.953       3.638
# Crypto_Global_Ranking                 0.0193      0.013      1.462      0.144      -0.007       0.045
# BTC_Price_Movement_ID_10              0.1806      0.344      0.525      0.600      -0.494       0.855
# =====================================================================================================

# %% [markdown]
# ## Model 3 deleting Gold, Copper, and News_Article_Count

# %%
logreg3 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Doge_Price + Litecoin_Price + SP500 + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Singapore_Dollar + Euro + Tweet_Average_Sentiment + News_Sentiment + Crypto_Global_Ranking + BTC_Price_Movement_ID_10',
                   data = DoD_train).fit()
print(logreg3.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.482583
#          Iterations 7
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      386
# Method:                                  MLE   Df Model:                           18
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.3008
# Time:                               18:08:06   Log-Likelihood:                -195.45
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 2.066e-26
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           -44.9643     38.175     -1.178      0.239    -119.785      29.857
# Bitcoin_Volume                     1.274e-11   1.26e-11      1.010      0.312    -1.2e-11    3.75e-11
# Bitcoin_Price                         0.0016      0.000      6.322      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0001      0.000      0.683      0.495      -0.000       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.649      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.48e-05     -3.930      0.000      -0.000      -0.000
# Ethereum_Price                       -0.0005      0.000     -1.040      0.298      -0.001       0.000
# Doge_Price                           -5.2221      9.136     -0.572      0.568     -23.129      12.685
# Litecoin_Price                       -0.0098      0.013     -0.779      0.436      -0.034       0.015
# SP500                                 0.0008      0.001      0.640      0.522      -0.002       0.003
# UST_1Y_Maturity                     -49.9041     62.019     -0.805      0.421    -171.459      71.651
# UST_10Y_Maturity                     99.1451     88.320      1.123      0.262     -73.960     272.250
# Crude_Oil                            -0.0212      0.015     -1.397      0.162      -0.051       0.009
# Singapore_Dollar                     17.5711     18.574      0.946      0.344     -18.834      53.976
# Euro                                 16.8152     10.312      1.631      0.103      -3.395      37.026
# Tweet_Average_Sentiment              19.9813     11.991      1.666      0.096      -3.520      43.483
# News_Sentiment                       -1.6704      2.691     -0.621      0.535      -6.946       3.605
# Crypto_Global_Ranking                 0.0191      0.013      1.478      0.139      -0.006       0.044
# BTC_Price_Movement_ID_10              0.1821      0.344      0.529      0.597      -0.492       0.857
# =====================================================================================================

# %% [markdown]
# ## Model 4 deleting Doge_Price, SP500, News_Sentiment and BTC_Price_Movement_ID_10

# %%
logreg4 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Litecoin_Price + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Singapore_Dollar + Euro + Tweet_Average_Sentiment + Crypto_Global_Ranking',
                   data = DoD_train).fit()
print(logreg4.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.484688
#          Iterations 7
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      390
# Method:                                  MLE   Df Model:                           14
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.2978
# Time:                               18:12:44   Log-Likelihood:                -196.30
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 3.521e-28
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                           -27.6781     30.528     -0.907      0.365     -87.512      32.156
# Bitcoin_Volume                     1.178e-11   1.19e-11      0.986      0.324   -1.16e-11    3.52e-11
# Bitcoin_Price                         0.0016      0.000      7.025      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0002      0.000      1.419      0.156   -6.09e-05       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.733      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.41e-05     -3.999      0.000      -0.000      -0.000
# Ethereum_Price                       -0.0004      0.000     -0.945      0.345      -0.001       0.000
# Litecoin_Price                       -0.0157      0.010     -1.520      0.129      -0.036       0.005
# UST_1Y_Maturity                     -52.2039     61.269     -0.852      0.394    -172.289      67.881
# UST_10Y_Maturity                     82.3487     83.896      0.982      0.326     -82.085     246.782
# Crude_Oil                            -0.0239      0.014     -1.664      0.096      -0.052       0.004
# Singapore_Dollar                     10.8836     15.880      0.685      0.493     -20.240      42.008
# Euro                                 12.8000      9.252      1.384      0.167      -5.333      30.933
# Tweet_Average_Sentiment              17.9526     11.628      1.544      0.123      -4.837      40.743
# Crypto_Global_Ranking                 0.0173      0.012      1.409      0.159      -0.007       0.041
# =====================================================================================================

# %% [markdown]
# # Model 5 deleting Singapore_Dollar

# %%
logreg5 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Ethereum_Price + Litecoin_Price + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Euro + Tweet_Average_Sentiment + Crypto_Global_Ranking',
                   data = DoD_train).fit()
print(logreg5.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.485270
#          Iterations 7
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      391
# Method:                                  MLE   Df Model:                           13
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.2969
# Time:                               18:13:51   Log-Likelihood:                -196.53
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 1.195e-28
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -7.1189      5.634     -1.264      0.206     -18.161       3.923
# Bitcoin_Volume                     1.326e-11   1.18e-11      1.119      0.263   -9.95e-12    3.65e-11
# Bitcoin_Price                         0.0016      0.000      7.049      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0002      0.000      1.401      0.161    -6.3e-05       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.743      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.32e-05     -4.204      0.000      -0.000      -0.000
# Ethereum_Price                       -0.0004      0.000     -0.942      0.346      -0.001       0.000
# Litecoin_Price                       -0.0148      0.010     -1.447      0.148      -0.035       0.005
# UST_1Y_Maturity                     -69.5346     55.870     -1.245      0.213    -179.038      39.969
# UST_10Y_Maturity                    108.4948     74.843      1.450      0.147     -38.194     255.184
# Crude_Oil                            -0.0274      0.013     -2.039      0.041      -0.054      -0.001
# Euro                                  7.5540      5.180      1.458      0.145      -2.600      17.708
# Tweet_Average_Sentiment              17.6096     11.584      1.520      0.128      -5.094      40.314
# Crypto_Global_Ranking                 0.0183      0.012      1.499      0.134      -0.006       0.042
# =====================================================================================================

# %% [markdown]
# ## Model 6 deleting Ethereum_Price

# %%
logreg6 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Volume + Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Litecoin_Price + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Euro + Tweet_Average_Sentiment + Crypto_Global_Ranking',
                   data = DoD_train).fit()
print(logreg6.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.486369
#          Iterations 8
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      392
# Method:                                  MLE   Df Model:                           12
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.2953
# Time:                               18:17:11   Log-Likelihood:                -196.98
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 4.754e-29
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -5.8598      5.466     -1.072      0.284     -16.573       4.853
# Bitcoin_Volume                     1.308e-11   1.18e-11      1.110      0.267      -1e-11    3.62e-11
# Bitcoin_Price                         0.0016      0.000      7.035      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0002      0.000      1.374      0.170   -6.59e-05       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.742      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.32e-05     -4.160      0.000      -0.000      -0.000
# Litecoin_Price                       -0.0214      0.008     -2.831      0.005      -0.036      -0.007
# UST_1Y_Maturity                     -69.6198     55.827     -1.247      0.212    -179.040      39.800
# UST_10Y_Maturity                    108.9191     74.719      1.458      0.145     -37.526     255.365
# Crude_Oil                            -0.0277      0.013     -2.064      0.039      -0.054      -0.001
# Euro                                  6.0916      4.935      1.234      0.217      -3.582      15.765
# Tweet_Average_Sentiment              17.5660     11.596      1.515      0.130      -5.161      40.293
# Crypto_Global_Ranking                 0.0196      0.012      1.626      0.104      -0.004       0.043
# =====================================================================================================

# %% [markdown]
# ## Model 7 deleting Bitcoin_Volume

# %%
logreg7 = smf.logit(formula = 'BTC_Price_Movement_DOD_10 ~ Bitcoin_Price + Bitcoin_Price_Close + Bitcoin_Price_Previous_Day_Open + Bitcoin_Price_One_Week_Prior_Open + Litecoin_Price + UST_1Y_Maturity + UST_10Y_Maturity + Crude_Oil + Euro + Tweet_Average_Sentiment + Crypto_Global_Ranking',
                   data = DoD_train).fit()
print(logreg7.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.487956
#          Iterations 8
#                                Logit Regression Results
# =====================================================================================
# Dep. Variable:     BTC_Price_Movement_DOD_10   No. Observations:                  405
# Model:                                 Logit   Df Residuals:                      393
# Method:                                  MLE   Df Model:                           11
# Date:                       Sun, 23 Apr 2023   Pseudo R-squ.:                  0.2930
# Time:                               18:17:35   Log-Likelihood:                -197.62
# converged:                              True   LL-Null:                       -279.54
# Covariance Type:                   nonrobust   LLR p-value:                 2.189e-29
# =====================================================================================================
#                                         coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# Intercept                            -4.7778      5.363     -0.891      0.373     -15.288       5.733
# Bitcoin_Price                         0.0016      0.000      7.056      0.000       0.001       0.002
# Bitcoin_Price_Close                   0.0002      0.000      1.378      0.168   -6.56e-05       0.000
# Bitcoin_Price_Previous_Day_Open      -0.0015      0.000     -7.755      0.000      -0.002      -0.001
# Bitcoin_Price_One_Week_Prior_Open    -0.0002   5.36e-05     -4.113      0.000      -0.000      -0.000
# Litecoin_Price                       -0.0209      0.008     -2.762      0.006      -0.036      -0.006
# UST_1Y_Maturity                     -66.2992     55.678     -1.191      0.234    -175.427      42.829
# UST_10Y_Maturity                    108.0477     74.478      1.451      0.147     -37.926     254.021
# Crude_Oil                            -0.0286      0.013     -2.134      0.033      -0.055      -0.002
# Euro                                  5.3880      4.881      1.104      0.270      -4.178      14.954
# Tweet_Average_Sentiment              16.9970     11.538      1.473      0.141      -5.616      39.610
# Crypto_Global_Ranking                 0.0198      0.012      1.639      0.101      -0.004       0.043
# =====================================================================================================
